# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/antonius/Projects/DS_Projects/Check-ups/3_Machine_learning/data/uk-used-cars/bmw.csv')

# %%
df.head(5)
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0

# %% [markdown]
# # Train, test, validation

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(df,train_size=0.6,random_state=42)

# %%
val, test = train_test_split(test,train_size=0.5,random_state=42)

# %% [markdown]
# ## Features lists

# %%
from catboost import CatBoostRegressor

# %%
X = ['model', 'year', 'transmission', 'mileage', 'fuelType', 'tax',
       'mpg', 'engineSize']

cat_features = ['model', 'transmission', 'fuelType']

y = ['price']

# %%
parameters = {'cat_features': cat_features,
              'eval_metric': 'MAPE',
              'learning_rate': 0.08,
              'random_seed':42,
              'verbose':100}

# %%
model = CatBoostRegressor(**parameters)

# %%
model.fit(train[X],train[y],eval_set=(val[X],val[y]))
# Out:
# 0:	learn: 0.4564416	test: 0.4521294	best: 0.4521294 (0)	total: 55ms	remaining: 54.9s
# 100:	learn: 0.0875290	test: 0.0867329	best: 0.0867329 (100)	total: 332ms	remaining: 2.95s
# 200:	learn: 0.0760834	test: 0.0779235	best: 0.0779235 (200)	total: 594ms	remaining: 2.36s
# 300:	learn: 0.0708670	test: 0.0740290	best: 0.0740290 (300)	total: 857ms	remaining: 1.99s
# 400:	learn: 0.0676240	test: 0.0718814	best: 0.0718814 (400)	total: 1.12s	remaining: 1.68s
# 500:	learn: 0.0654070	test: 0.0709221	best: 0.0708594 (496)	total: 1.39s	remaining: 1.38s
# 600:	learn: 0.0638577	test: 0.0704606	best: 0.0704490 (599)	total: 1.65s	remaining: 1.1s
# 700:	learn: 0.0622969	test: 0.0698226	best: 0.0698226 (700)	total: 1.92s	remaining: 819ms
# 800:	learn: 0.0609583	test: 0.0694169	best: 0.0694004 (791)	total: 2.19s	remaining: 544ms
# 900:	learn: 0.0596089	test: 0.0689968	best: 0.0689945 (895)	total: 2.45s	remaining: 269ms
# 999:	learn: 0.0584626	test: 0.0686829	best: 0.0686377 (993)	total: 2.72s	remaining: 0us
#
# bestTest = 0.06863774536
# bestIteration = 993
#
# Shrink model to first 994 iterations.

# %% [markdown]
# # Check on the test sample

# %%
test['price_pred'] = model.predict(test[X])

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error

# %%
def error(y_true,y_pred):
  print(mean_absolute_error(y_true,y_pred))
  print(mean_absolute_percentage_error(y_true,y_pred))

# %%
error(test['price'],test['price_pred'])
# Out:
# 1537.5600657036578
# 0.0724718966452533

# %% [markdown]
# # Error analysis

# %%
test['error'] = test['price_pred'] - test['price']

# %%
test.head()
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 4984         X6  2019  52990    Semi-Auto     3086   Diesel  145  34.9
# 4880         X1  2018  24081    Semi-Auto    13245   Diesel  150  60.1
# 9132   1 Series  2016  12999    Automatic    68949   Petrol  200  43.5
# 6451   1 Series  2020  11995    Semi-Auto       10   Petrol  150  34.5
# 7199   3 Series  2020  29875    Semi-Auto      150   Petrol  145  42.2
#
#       engineSize    price_pred         error
# 4984         3.0  56789.268481   3799.268481
# 4880         2.0  22236.888207  -1844.111793
# 9132         2.0  13529.705791    530.705791
# 6451         2.0  31815.676673  19820.676673
# 7199         2.0  35549.276658   5674.276658

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

# %%
test['error'].hist()
# Out:
# <AxesSubplot: >

# %%
test['error'].mean()
# Out:
# 122.08788795070966

# %% [markdown]
# # Observational error

# %%
test['error_abs'] = abs(test['error'])

# %%
test.head()
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 4984         X6  2019  52990    Semi-Auto     3086   Diesel  145  34.9
# 4880         X1  2018  24081    Semi-Auto    13245   Diesel  150  60.1
# 9132   1 Series  2016  12999    Automatic    68949   Petrol  200  43.5
# 6451   1 Series  2020  11995    Semi-Auto       10   Petrol  150  34.5
# 7199   3 Series  2020  29875    Semi-Auto      150   Petrol  145  42.2
#
#       engineSize    price_pred         error     error_abs
# 4984         3.0  56789.268481   3799.268481   3799.268481
# 4880         2.0  22236.888207  -1844.111793   1844.111793
# 9132         2.0  13529.705791    530.705791    530.705791
# 6451         2.0  31815.676673  19820.676673  19820.676673
# 7199         2.0  35549.276658   5674.276658   5674.276658

# %%
test['error_abs'].describe()
# Out:
# count     2157.000000
# mean      1537.560066
# std       1676.859544
# min          0.083199
# 25%        489.152540
# 50%       1073.305750
# 75%       1946.619471
# max      19820.676673
# Name: error_abs, dtype: float64

# %%
test.sort_values('error_abs',ascending=False).head(10)
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 6451   1 Series  2020  11995    Semi-Auto       10   Petrol  150  34.5
# 1244   4 Series  2020  47550    Semi-Auto      101   Diesel  145  60.1
# 6866   4 Series  2020  42520    Semi-Auto      102   Diesel  145  65.7
# 6592         M5  2019  70995    Semi-Auto       23   Petrol  145  24.1
# 2315         X2  2019  44980    Semi-Auto      500   Diesel  145  58.9
# 6270         M4  2020  59999    Semi-Auto     3000   Petrol  150  28.5
# 947    2 Series  2015  11998    Semi-Auto    30738   Diesel   20  68.9
# 6759   4 Series  2020  42495    Semi-Auto       18   Diesel  150  58.9
# 4833         M4  2019  58662    Automatic     3395   Petrol  145  34.0
# 6215         M4  2018  53999    Semi-Auto     8725   Petrol  145  33.6
#
#       engineSize    price_pred         error     error_abs
# 6451         2.0  31815.676673  19820.676673  19820.676673
# 1244         2.0  31822.814760 -15727.185240  15727.185240
# 6866         2.0  28016.370190 -14503.629810  14503.629810
# 6592         4.4  85092.283023  14097.283023  14097.283023
# 2315         2.0  32052.149452 -12927.850548  12927.850548
# 6270         3.0  47193.043921 -12805.956079  12805.956079
# 947          2.0  24663.932331  12665.932331  12665.932331
# 6759         2.0  30133.732400 -12361.267600  12361.267600
# 4833         3.0  46802.901943 -11859.098057  11859.098057
# 6215         3.0  42513.071957 -11485.928043  11485.928043

# %% [markdown]
# ## Analysis of the Observational error relative to the price

# %%
pd.qcut(test['price'],5)
# Out:
# 4984     (29990.0, 74990.0]
# 4880     (23131.6, 29990.0]
# 9132    (1199.999, 13995.0]
# 6451    (1199.999, 13995.0]
# 7199     (23131.6, 29990.0]
#                ...
# 9627     (13995.0, 18500.0]
# 6096     (23131.6, 29990.0]
# 1747     (29990.0, 74990.0]
# 4023     (13995.0, 18500.0]
# 4372     (23131.6, 29990.0]
# Name: price, Length: 2157, dtype: category
# Categories (5, interval[float64, right]): [(1199.999, 13995.0] < (13995.0, 18500.0] < (18500.0, 23131.6] < (23131.6, 29990.0] < (29990.0, 74990.0]]

# %%
test['price_group'] = pd.qcut(test['price'],5)

# %%
test.head(5)
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 4984         X6  2019  52990    Semi-Auto     3086   Diesel  145  34.9
# 4880         X1  2018  24081    Semi-Auto    13245   Diesel  150  60.1
# 9132   1 Series  2016  12999    Automatic    68949   Petrol  200  43.5
# 6451   1 Series  2020  11995    Semi-Auto       10   Petrol  150  34.5
# 7199   3 Series  2020  29875    Semi-Auto      150   Petrol  145  42.2
#
#       engineSize    price_pred         error     error_abs  \
# 4984         3.0  56789.268481   3799.268481   3799.268481
# 4880         2.0  22236.888207  -1844.111793   1844.111793
# 9132         2.0  13529.705791    530.705791    530.705791
# 6451         2.0  31815.676673  19820.676673  19820.676673
# 7199         2.0  35549.276658   5674.276658   5674.276658
#
#               price_group
# 4984   (29990.0, 74990.0]
# 4880   (23131.6, 29990.0]
# 9132  (1199.999, 13995.0]
# 6451  (1199.999, 13995.0]
# 7199   (23131.6, 29990.0]

# %%
test.groupby('price_group')[['error_abs','error']].agg(['count','mean'])
# Out:
#                     error_abs              error
#                         count         mean count        mean
# price_group
# (1199.999, 13995.0]       435   911.712080   435  462.229738
# (13995.0, 18500.0]        432  1151.556512   432  281.411969
# (18500.0, 23131.6]        427  1318.846517   427  254.475675
# (23131.6, 29990.0]        432  1749.723698   432  378.241254
# (29990.0, 74990.0]        431  2560.143373   431 -768.811293

# %%
t = test.groupby('price_group')[['error_abs','error']].agg(['count','mean'])

# %%
t.columns = ['_'.join(col).strip() for col in t.columns.values]

# %%
t = t.drop('error_count',axis=1)

# %%
t['mean_error_diff'] = t['error_abs_mean'] - test['error_abs'].mean()

# %%
t['mean_error'] = test['error_abs'].mean()

# %%
import seaborn as sns
cm = sns.dark_palette("red", as_cmap=True)

# %%
t.style.background_gradient(cmap=cm,subset=['mean_error_diff'])
# Out:
# <style type="text/css">
# #T_fdcd1_row0_col3 {
#   background-color: #312222;
#   color: #f1f1f1;
# }
# #T_fdcd1_row1_col3 {
#   background-color: #4f1d1d;
#   color: #f1f1f1;
# }
# #T_fdcd1_row2_col3 {
#   background-color: #641a1a;
#   color: #f1f1f1;
# }
# #T_fdcd1_row3_col3 {
#   background-color: #9a1111;
#   color: #f1f1f1;
# }
# #T_fdcd1_row4_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fdcd1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fdcd1_level0_col0" class="col_heading level0 col0" >error_abs_count</th>
#       <th id="T_fdcd1_level0_col1" class="col_heading level0 col1" >error_abs_mean</th>
#       <th id="T_fdcd1_level0_col2" class="col_heading level0 col2" >error_mean</th>
#       <th id="T_fdcd1_level0_col3" class="col_heading level0 col3" >mean_error_diff</th>
#       <th id="T_fdcd1_level0_col4" class="col_heading level0 col4" >mean_error</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >price_group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fdcd1_level0_row0" class="row_heading level0 row0" >(1199.999, 13995.0]</th>
#       <td id="T_fdcd1_row0_col0" class="data row0 col0" >435</td>
#       <td id="T_fdcd1_row0_col1" class="data row0 col1" >911.712080</td>
#       <td id="T_fdcd1_row0_col2" class="data row0 col2" >462.229738</td>
#       <td id="T_fdcd1_row0_col3" class="data row0 col3" >-625.847985</td>
#       <td id="T_fdcd1_row0_col4" class="data row0 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_fdcd1_level0_row1" class="row_heading level0 row1" >(13995.0, 18500.0]</th>
#       <td id="T_fdcd1_row1_col0" class="data row1 col0" >432</td>
#       <td id="T_fdcd1_row1_col1" class="data row1 col1" >1151.556512</td>
#       <td id="T_fdcd1_row1_col2" class="data row1 col2" >281.411969</td>
#       <td id="T_fdcd1_row1_col3" class="data row1 col3" >-386.003554</td>
#       <td id="T_fdcd1_row1_col4" class="data row1 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_fdcd1_level0_row2" class="row_heading level0 row2" >(18500.0, 23131.6]</th>
#       <td id="T_fdcd1_row2_col0" class="data row2 col0" >427</td>
#       <td id="T_fdcd1_row2_col1" class="data row2 col1" >1318.846517</td>
#       <td id="T_fdcd1_row2_col2" class="data row2 col2" >254.475675</td>
#       <td id="T_fdcd1_row2_col3" class="data row2 col3" >-218.713549</td>
#       <td id="T_fdcd1_row2_col4" class="data row2 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_fdcd1_level0_row3" class="row_heading level0 row3" >(23131.6, 29990.0]</th>
#       <td id="T_fdcd1_row3_col0" class="data row3 col0" >432</td>
#       <td id="T_fdcd1_row3_col1" class="data row3 col1" >1749.723698</td>
#       <td id="T_fdcd1_row3_col2" class="data row3 col2" >378.241254</td>
#       <td id="T_fdcd1_row3_col3" class="data row3 col3" >212.163632</td>
#       <td id="T_fdcd1_row3_col4" class="data row3 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_fdcd1_level0_row4" class="row_heading level0 row4" >(29990.0, 74990.0]</th>
#       <td id="T_fdcd1_row4_col0" class="data row4 col0" >431</td>
#       <td id="T_fdcd1_row4_col1" class="data row4 col1" >2560.143373</td>
#       <td id="T_fdcd1_row4_col2" class="data row4 col2" >-768.811293</td>
#       <td id="T_fdcd1_row4_col3" class="data row4 col3" >1022.583307</td>
#       <td id="T_fdcd1_row4_col4" class="data row4 col4" >1537.560066</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Analysis of the Observational error relative to other variables

# %%
test.head(5)
# Out:
#           model  year  price transmission  mileage fuelType  tax   mpg  \
# 4984         X6  2019  52990    Semi-Auto     3086   Diesel  145  34.9
# 4880         X1  2018  24081    Semi-Auto    13245   Diesel  150  60.1
# 9132   1 Series  2016  12999    Automatic    68949   Petrol  200  43.5
# 6451   1 Series  2020  11995    Semi-Auto       10   Petrol  150  34.5
# 7199   3 Series  2020  29875    Semi-Auto      150   Petrol  145  42.2
#
#       engineSize    price_pred         error     error_abs  \
# 4984         3.0  56789.268481   3799.268481   3799.268481
# 4880         2.0  22236.888207  -1844.111793   1844.111793
# 9132         2.0  13529.705791    530.705791    530.705791
# 6451         2.0  31815.676673  19820.676673  19820.676673
# 7199         2.0  35549.276658   5674.276658   5674.276658
#
#               price_group
# 4984   (29990.0, 74990.0]
# 4880   (23131.6, 29990.0]
# 9132  (1199.999, 13995.0]
# 6451  (1199.999, 13995.0]
# 7199   (23131.6, 29990.0]

# %%
t = test.groupby('year')[['error_abs','error']].agg(['count','mean'])

# %%
t.columns = ['_'.join(col).strip() for col in t.columns.values]

# %%
t = t.drop('error_count',axis=1)

# %%
t['mean_error_diff'] = t['error_abs_mean'] - test['error_abs'].mean()

# %%
t['mean_error'] = test['error_abs'].mean()

# %%
t.style.background_gradient(cmap=cm,subset=['mean_error_diff'])
# Out:
# <style type="text/css">
# #T_e02a5_row0_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_e02a5_row1_col3, #T_e02a5_row12_col3, #T_e02a5_row14_col3 {
#   background-color: #3b2020;
#   color: #f1f1f1;
# }
# #T_e02a5_row2_col3 {
#   background-color: #3c2020;
#   color: #f1f1f1;
# }
# #T_e02a5_row3_col3 {
#   background-color: #6a1919;
#   color: #f1f1f1;
# }
# #T_e02a5_row4_col3, #T_e02a5_row18_col3 {
#   background-color: #511d1d;
#   color: #f1f1f1;
# }
# #T_e02a5_row5_col3 {
#   background-color: #5f1a1a;
#   color: #f1f1f1;
# }
# #T_e02a5_row6_col3 {
#   background-color: #571c1c;
#   color: #f1f1f1;
# }
# #T_e02a5_row7_col3 {
#   background-color: #3f2020;
#   color: #f1f1f1;
# }
# #T_e02a5_row8_col3 {
#   background-color: #8e1313;
#   color: #f1f1f1;
# }
# #T_e02a5_row9_col3 {
#   background-color: #342121;
#   color: #f1f1f1;
# }
# #T_e02a5_row10_col3 {
#   background-color: #411f1f;
#   color: #f1f1f1;
# }
# #T_e02a5_row11_col3 {
#   background-color: #312222;
#   color: #f1f1f1;
# }
# #T_e02a5_row13_col3 {
#   background-color: #401f1f;
#   color: #f1f1f1;
# }
# #T_e02a5_row15_col3 {
#   background-color: #4b1e1e;
#   color: #f1f1f1;
# }
# #T_e02a5_row16_col3 {
#   background-color: #402020;
#   color: #f1f1f1;
# }
# #T_e02a5_row17_col3 {
#   background-color: #461e1e;
#   color: #f1f1f1;
# }
# #T_e02a5_row19_col3 {
#   background-color: #5e1a1a;
#   color: #f1f1f1;
# }
# #T_e02a5_row20_col3 {
#   background-color: #841414;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e02a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e02a5_level0_col0" class="col_heading level0 col0" >error_abs_count</th>
#       <th id="T_e02a5_level0_col1" class="col_heading level0 col1" >error_abs_mean</th>
#       <th id="T_e02a5_level0_col2" class="col_heading level0 col2" >error_mean</th>
#       <th id="T_e02a5_level0_col3" class="col_heading level0 col3" >mean_error_diff</th>
#       <th id="T_e02a5_level0_col4" class="col_heading level0 col4" >mean_error</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e02a5_level0_row0" class="row_heading level0 row0" >1996</th>
#       <td id="T_e02a5_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_e02a5_row0_col1" class="data row0 col1" >6339.136209</td>
#       <td id="T_e02a5_row0_col2" class="data row0 col2" >6339.136209</td>
#       <td id="T_e02a5_row0_col3" class="data row0 col3" >4801.576144</td>
#       <td id="T_e02a5_row0_col4" class="data row0 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_e02a5_level0_row1" class="row_heading level0 row1" >1999</th>
#       <td id="T_e02a5_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_e02a5_row1_col1" class="data row1 col1" >890.056901</td>
#       <td id="T_e02a5_row1_col2" class="data row1 col2" >890.056901</td>
#       <td id="T_e02a5_row1_col3" class="data row1 col3" >-647.503164</td>
#       <td id="T_e02a5_row1_col4" class="data row1 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_e02a5_level0_row2" class="row_heading level0 row2" >2001</th>
#       <td id="T_e02a5_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_e02a5_row2_col1" class="data row2 col1" >927.316449</td>
#       <td id="T_e02a5_row2_col2" class="data row2 col2" >927.316449</td>
#       <td id="T_e02a5_row2_col3" class="data row2 col3" >-610.243617</td>
#       <td id="T_e02a5_row2_col4" class="data row2 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_e02a5_level0_row3" class="row_heading level0 row3" >2002</th>
#       <td id="T_e02a5_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_e02a5_row3_col1" class="data row3 col1" >2175.440983</td>
#       <td id="T_e02a5_row3_col2" class="data row3 col2" >-1069.308819</td>
#       <td id="T_e02a5_row3_col3" class="data row3 col3" >637.880917</td>
#       <td id="T_e02a5_row3_col4" class="data row3 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_e02a5_level0_row4" class="row_heading level0 row4" >2003</th>
#       <td id="T_e02a5_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_e02a5_row4_col1" class="data row4 col1" >1482.424637</td>
#       <td id="T_e02a5_row4_col2" class="data row4 col2" >-1482.424637</td>
#       <td id="T_e02a5_row4_col3" class="data row4 col3" >-55.135428</td>
#       <td id="T_e02a5_row4_col4" class="data row4 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_e02a5_level0_row5" class="row_heading level0 row5" >2004</th>
#       <td id="T_e02a5_row5_col0" class="data row5 col0" >4</td>
#       <td id="T_e02a5_row5_col1" class="data row5 col1" >1902.279284</td>
#       <td id="T_e02a5_row5_col2" class="data row5 col2" >-305.313519</td>
#       <td id="T_e02a5_row5_col3" class="data row5 col3" >364.719218</td>
#       <td id="T_e02a5_row5_col4" class="data row5 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_e02a5_level0_row6" class="row_heading level0 row6" >2006</th>
#       <td id="T_e02a5_row6_col0" class="data row6 col0" >3</td>
#       <td id="T_e02a5_row6_col1" class="data row6 col1" >1660.249510</td>
#       <td id="T_e02a5_row6_col2" class="data row6 col2" >775.274447</td>
#       <td id="T_e02a5_row6_col3" class="data row6 col3" >122.689445</td>
#       <td id="T_e02a5_row6_col4" class="data row6 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_e02a5_level0_row7" class="row_heading level0 row7" >2007</th>
#       <td id="T_e02a5_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_e02a5_row7_col1" class="data row7 col1" >1003.062275</td>
#       <td id="T_e02a5_row7_col2" class="data row7 col2" >1003.062275</td>
#       <td id="T_e02a5_row7_col3" class="data row7 col3" >-534.497791</td>
#       <td id="T_e02a5_row7_col4" class="data row7 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_e02a5_level0_row8" class="row_heading level0 row8" >2008</th>
#       <td id="T_e02a5_row8_col0" class="data row8 col0" >4</td>
#       <td id="T_e02a5_row8_col1" class="data row8 col1" >3182.698112</td>
#       <td id="T_e02a5_row8_col2" class="data row8 col2" >3182.698112</td>
#       <td id="T_e02a5_row8_col3" class="data row8 col3" >1645.138047</td>
#       <td id="T_e02a5_row8_col4" class="data row8 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_e02a5_level0_row9" class="row_heading level0 row9" >2009</th>
#       <td id="T_e02a5_row9_col0" class="data row9 col0" >6</td>
#       <td id="T_e02a5_row9_col1" class="data row9 col1" >703.048594</td>
#       <td id="T_e02a5_row9_col2" class="data row9 col2" >84.183919</td>
#       <td id="T_e02a5_row9_col3" class="data row9 col3" >-834.511472</td>
#       <td id="T_e02a5_row9_col4" class="data row9 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_e02a5_level0_row10" class="row_heading level0 row10" >2010</th>
#       <td id="T_e02a5_row10_col0" class="data row10 col0" >3</td>
#       <td id="T_e02a5_row10_col1" class="data row10 col1" >1059.354320</td>
#       <td id="T_e02a5_row10_col2" class="data row10 col2" >695.204249</td>
#       <td id="T_e02a5_row10_col3" class="data row10 col3" >-478.205745</td>
#       <td id="T_e02a5_row10_col4" class="data row10 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_e02a5_level0_row11" class="row_heading level0 row11" >2011</th>
#       <td id="T_e02a5_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_e02a5_row11_col1" class="data row11 col1" >605.873341</td>
#       <td id="T_e02a5_row11_col2" class="data row11 col2" >428.301728</td>
#       <td id="T_e02a5_row11_col3" class="data row11 col3" >-931.686725</td>
#       <td id="T_e02a5_row11_col4" class="data row11 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_e02a5_level0_row12" class="row_heading level0 row12" >2012</th>
#       <td id="T_e02a5_row12_col0" class="data row12 col0" >28</td>
#       <td id="T_e02a5_row12_col1" class="data row12 col1" >888.946275</td>
#       <td id="T_e02a5_row12_col2" class="data row12 col2" >26.555228</td>
#       <td

# %%
def print_error(col):
  t = test.groupby(col)[['error_abs','error']].agg(['count','mean'])
  t.columns = ['_'.join(col).strip() for col in t.columns.values]
  t = t.drop('error_count',axis=1)
  t['mean_error_diff'] = t['error_abs_mean'] - test['error_abs'].mean()
  t['mean_error'] = test['error_abs'].mean()
  display(t.style.background_gradient(cmap=cm,subset=['mean_error_diff']))

# %%
print_error('year')
# Out:
# <style type="text/css">
# #T_b6487_row0_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_b6487_row1_col3, #T_b6487_row12_col3, #T_b6487_row14_col3 {
#   background-color: #3b2020;
#   color: #f1f1f1;
# }
# #T_b6487_row2_col3 {
#   background-color: #3c2020;
#   color: #f1f1f1;
# }
# #T_b6487_row3_col3 {
#   background-color: #6a1919;
#   color: #f1f1f1;
# }
# #T_b6487_row4_col3, #T_b6487_row18_col3 {
#   background-color: #511d1d;
#   color: #f1f1f1;
# }
# #T_b6487_row5_col3 {
#   background-color: #5f1a1a;
#   color: #f1f1f1;
# }
# #T_b6487_row6_col3 {
#   background-color: #571c1c;
#   color: #f1f1f1;
# }
# #T_b6487_row7_col3 {
#   background-color: #3f2020;
#   color: #f1f1f1;
# }
# #T_b6487_row8_col3 {
#   background-color: #8e1313;
#   color: #f1f1f1;
# }
# #T_b6487_row9_col3 {
#   background-color: #342121;
#   color: #f1f1f1;
# }
# #T_b6487_row10_col3 {
#   background-color: #411f1f;
#   color: #f1f1f1;
# }
# #T_b6487_row11_col3 {
#   background-color: #312222;
#   color: #f1f1f1;
# }
# #T_b6487_row13_col3 {
#   background-color: #401f1f;
#   color: #f1f1f1;
# }
# #T_b6487_row15_col3 {
#   background-color: #4b1e1e;
#   color: #f1f1f1;
# }
# #T_b6487_row16_col3 {
#   background-color: #402020;
#   color: #f1f1f1;
# }
# #T_b6487_row17_col3 {
#   background-color: #461e1e;
#   color: #f1f1f1;
# }
# #T_b6487_row19_col3 {
#   background-color: #5e1a1a;
#   color: #f1f1f1;
# }
# #T_b6487_row20_col3 {
#   background-color: #841414;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b6487">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6487_level0_col0" class="col_heading level0 col0" >error_abs_count</th>
#       <th id="T_b6487_level0_col1" class="col_heading level0 col1" >error_abs_mean</th>
#       <th id="T_b6487_level0_col2" class="col_heading level0 col2" >error_mean</th>
#       <th id="T_b6487_level0_col3" class="col_heading level0 col3" >mean_error_diff</th>
#       <th id="T_b6487_level0_col4" class="col_heading level0 col4" >mean_error</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6487_level0_row0" class="row_heading level0 row0" >1996</th>
#       <td id="T_b6487_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_b6487_row0_col1" class="data row0 col1" >6339.136209</td>
#       <td id="T_b6487_row0_col2" class="data row0 col2" >6339.136209</td>
#       <td id="T_b6487_row0_col3" class="data row0 col3" >4801.576144</td>
#       <td id="T_b6487_row0_col4" class="data row0 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_b6487_level0_row1" class="row_heading level0 row1" >1999</th>
#       <td id="T_b6487_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_b6487_row1_col1" class="data row1 col1" >890.056901</td>
#       <td id="T_b6487_row1_col2" class="data row1 col2" >890.056901</td>
#       <td id="T_b6487_row1_col3" class="data row1 col3" >-647.503164</td>
#       <td id="T_b6487_row1_col4" class="data row1 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_b6487_level0_row2" class="row_heading level0 row2" >2001</th>
#       <td id="T_b6487_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_b6487_row2_col1" class="data row2 col1" >927.316449</td>
#       <td id="T_b6487_row2_col2" class="data row2 col2" >927.316449</td>
#       <td id="T_b6487_row2_col3" class="data row2 col3" >-610.243617</td>
#       <td id="T_b6487_row2_col4" class="data row2 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_b6487_level0_row3" class="row_heading level0 row3" >2002</th>
#       <td id="T_b6487_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_b6487_row3_col1" class="data row3 col1" >2175.440983</td>
#       <td id="T_b6487_row3_col2" class="data row3 col2" >-1069.308819</td>
#       <td id="T_b6487_row3_col3" class="data row3 col3" >637.880917</td>
#       <td id="T_b6487_row3_col4" class="data row3 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_b6487_level0_row4" class="row_heading level0 row4" >2003</th>
#       <td id="T_b6487_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_b6487_row4_col1" class="data row4 col1" >1482.424637</td>
#       <td id="T_b6487_row4_col2" class="data row4 col2" >-1482.424637</td>
#       <td id="T_b6487_row4_col3" class="data row4 col3" >-55.135428</td>
#       <td id="T_b6487_row4_col4" class="data row4 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_b6487_level0_row5" class="row_heading level0 row5" >2004</th>
#       <td id="T_b6487_row5_col0" class="data row5 col0" >4</td>
#       <td id="T_b6487_row5_col1" class="data row5 col1" >1902.279284</td>
#       <td id="T_b6487_row5_col2" class="data row5 col2" >-305.313519</td>
#       <td id="T_b6487_row5_col3" class="data row5 col3" >364.719218</td>
#       <td id="T_b6487_row5_col4" class="data row5 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_b6487_level0_row6" class="row_heading level0 row6" >2006</th>
#       <td id="T_b6487_row6_col0" class="data row6 col0" >3</td>
#       <td id="T_b6487_row6_col1" class="data row6 col1" >1660.249510</td>
#       <td id="T_b6487_row6_col2" class="data row6 col2" >775.274447</td>
#       <td id="T_b6487_row6_col3" class="data row6 col3" >122.689445</td>
#       <td id="T_b6487_row6_col4" class="data row6 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_b6487_level0_row7" class="row_heading level0 row7" >2007</th>
#       <td id="T_b6487_row7_col0" class="data row7 col0" >2</td>
#       <td id="T_b6487_row7_col1" class="data row7 col1" >1003.062275</td>
#       <td id="T_b6487_row7_col2" class="data row7 col2" >1003.062275</td>
#       <td id="T_b6487_row7_col3" class="data row7 col3" >-534.497791</td>
#       <td id="T_b6487_row7_col4" class="data row7 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_b6487_level0_row8" class="row_heading level0 row8" >2008</th>
#       <td id="T_b6487_row8_col0" class="data row8 col0" >4</td>
#       <td id="T_b6487_row8_col1" class="data row8 col1" >3182.698112</td>
#       <td id="T_b6487_row8_col2" class="data row8 col2" >3182.698112</td>
#       <td id="T_b6487_row8_col3" class="data row8 col3" >1645.138047</td>
#       <td id="T_b6487_row8_col4" class="data row8 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_b6487_level0_row9" class="row_heading level0 row9" >2009</th>
#       <td id="T_b6487_row9_col0" class="data row9 col0" >6</td>
#       <td id="T_b6487_row9_col1" class="data row9 col1" >703.048594</td>
#       <td id="T_b6487_row9_col2" class="data row9 col2" >84.183919</td>
#       <td id="T_b6487_row9_col3" class="data row9 col3" >-834.511472</td>
#       <td id="T_b6487_row9_col4" class="data row9 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_b6487_level0_row10" class="row_heading level0 row10" >2010</th>
#       <td id="T_b6487_row10_col0" class="data row10 col0" >3</td>
#       <td id="T_b6487_row10_col1" class="data row10 col1" >1059.354320</td>
#       <td id="T_b6487_row10_col2" class="data row10 col2" >695.204249</td>
#       <td id="T_b6487_row10_col3" class="data row10 col3" >-478.205745</td>
#       <td id="T_b6487_row10_col4" class="data row10 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_b6487_level0_row11" class="row_heading level0 row11" >2011</th>
#       <td id="T_b6487_row11_col0" class="data row11 col0" >12</td>
#       <td id="T_b6487_row11_col1" class="data row11 col1" >605.873341</td>
#       <td id="T_b6487_row11_col2" class="data row11 col2" >428.301728</td>
#       <td id="T_b6487_row11_col3" class="data row11 col3" >-931.686725</td>
#       <td id="T_b6487_row11_col4" class="data row11 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_b6487_level0_row12" class="row_heading level0 row12" >2012</th>
#       <td id="T_b6487_row12_col0" class="data row12 col0" >28</td>
#       <td id="T_b6487_row12_col1" class="data row12 col1" >888.946275</td>
#       <td id="T_b6487_row12_col2" class="data row12 col2" >26.555228</td>
#       <td

# %%
test
# Out:
#           model  year  price transmission  mileage fuelType  tax    mpg  \
# 4984         X6  2019  52990    Semi-Auto     3086   Diesel  145   34.9
# 4880         X1  2018  24081    Semi-Auto    13245   Diesel  150   60.1
# 9132   1 Series  2016  12999    Automatic    68949   Petrol  200   43.5
# 6451   1 Series  2020  11995    Semi-Auto       10   Petrol  150   34.5
# 7199   3 Series  2020  29875    Semi-Auto      150   Petrol  145   42.2
# ...         ...   ...    ...          ...      ...      ...  ...    ...
# 9627   3 Series  2015  14999    Automatic    78680   Diesel  160   52.3
# 6096   4 Series  2019  29676    Automatic     7365   Petrol  145   41.5
# 1747   5 Series  2019  30570    Automatic     3067   Hybrid  145   49.6
# 4023   3 Series  2016  14999    Automatic    70054   Hybrid    0  148.7
# 4372   2 Series  2019  24590    Semi-Auto     3300   Diesel  145   48.7
#
#       engineSize    price_pred         error     error_abs  \
# 4984         3.0  56789.268481   3799.268481   3799.268481
# 4880         2.0  22236.888207  -1844.111793   1844.111793
# 9132         2.0  13529.705791    530.705791    530.705791
# 6451         2.0  31815.676673  19820.676673  19820.676673
# 7199         2.0  35549.276658   5674.276658   5674.276658
# ...          ...           ...           ...           ...
# 9627         3.0  14193.617089   -805.382911    805.382911
# 6096         3.0  30819.807549   1143.807549   1143.807549
# 1747         2.0  29782.428096   -787.571904    787.571904
# 4023         2.0  13799.641665  -1199.358335   1199.358335
# 4372         2.0  24591.487081      1.487081      1.487081
#
#               price_group
# 4984   (29990.0, 74990.0]
# 4880   (23131.6, 29990.0]
# 9132  (1199.999, 13995.0]
# 6451  (1199.999, 13995.0]
# 7199   (23131.6, 29990.0]
# ...                   ...
# 9627   (13995.0, 18500.0]
# 6096   (23131.6, 29990.0]
# 1747   (29990.0, 74990.0]
# 4023   (13995.0, 18500.0]
# 4372   (23131.6, 29990.0]
#
# [2157 rows x 13 columns]

# %%
print_error('transmission')
# Out:
# <style type="text/css">
# #T_6d26b_row0_col3 {
#   background-color: #a60f0f;
#   color: #f1f1f1;
# }
# #T_6d26b_row1_col3 {
#   background-color: #312222;
#   color: #f1f1f1;
# }
# #T_6d26b_row2_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6d26b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d26b_level0_col0" class="col_heading level0 col0" >error_abs_count</th>
#       <th id="T_6d26b_level0_col1" class="col_heading level0 col1" >error_abs_mean</th>
#       <th id="T_6d26b_level0_col2" class="col_heading level0 col2" >error_mean</th>
#       <th id="T_6d26b_level0_col3" class="col_heading level0 col3" >mean_error_diff</th>
#       <th id="T_6d26b_level0_col4" class="col_heading level0 col4" >mean_error</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >transmission</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d26b_level0_row0" class="row_heading level0 row0" >Automatic</th>
#       <td id="T_6d26b_row0_col0" class="data row0 col0" >695</td>
#       <td id="T_6d26b_row0_col1" class="data row0 col1" >1494.208611</td>
#       <td id="T_6d26b_row0_col2" class="data row0 col2" >36.406949</td>
#       <td id="T_6d26b_row0_col3" class="data row0 col3" >-43.351455</td>
#       <td id="T_6d26b_row0_col4" class="data row0 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_6d26b_level0_row1" class="row_heading level0 row1" >Manual</th>
#       <td id="T_6d26b_row1_col0" class="data row1 col0" >504</td>
#       <td id="T_6d26b_row1_col1" class="data row1 col1" >1079.145745</td>
#       <td id="T_6d26b_row1_col2" class="data row1 col2" >142.507574</td>
#       <td id="T_6d26b_row1_col3" class="data row1 col3" >-458.414320</td>
#       <td id="T_6d26b_row1_col4" class="data row1 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_6d26b_level0_row2" class="row_heading level0 row2" >Semi-Auto</th>
#       <td id="T_6d26b_row2_col0" class="data row2 col0" >958</td>
#       <td id="T_6d26b_row2_col1" class="data row2 col1" >1810.180189</td>
#       <td id="T_6d26b_row2_col2" class="data row2 col2" >173.504100</td>
#       <td id="T_6d26b_row2_col3" class="data row2 col3" >272.620124</td>
#       <td id="T_6d26b_row2_col4" class="data row2 col4" >1537.560066</td>
#     </tr>
#   </tbody>
# </table>

# %%
test['mileage_group'] = pd.qcut(test['mileage'],5)

# %%
print_error('mileage_group')
# Out:
# <style type="text/css">
# #T_bcab8_row0_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_bcab8_row1_col3 {
#   background-color: #9a1111;
#   color: #f1f1f1;
# }
# #T_bcab8_row2_col3 {
#   background-color: #6a1818;
#   color: #f1f1f1;
# }
# #T_bcab8_row3_col3 {
#   background-color: #461e1e;
#   color: #f1f1f1;
# }
# #T_bcab8_row4_col3 {
#   background-color: #312222;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bcab8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bcab8_level0_col0" class="col_heading level0 col0" >error_abs_count</th>
#       <th id="T_bcab8_level0_col1" class="col_heading level0 col1" >error_abs_mean</th>
#       <th id="T_bcab8_level0_col2" class="col_heading level0 col2" >error_mean</th>
#       <th id="T_bcab8_level0_col3" class="col_heading level0 col3" >mean_error_diff</th>
#       <th id="T_bcab8_level0_col4" class="col_heading level0 col4" >mean_error</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >mileage_group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bcab8_level0_row0" class="row_heading level0 row0" >(0.999, 4063.2]</th>
#       <td id="T_bcab8_row0_col0" class="data row0 col0" >432</td>
#       <td id="T_bcab8_row0_col1" class="data row0 col1" >2433.845556</td>
#       <td id="T_bcab8_row0_col2" class="data row0 col2" >293.238143</td>
#       <td id="T_bcab8_row0_col3" class="data row0 col3" >896.285490</td>
#       <td id="T_bcab8_row0_col4" class="data row0 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_bcab8_level0_row1" class="row_heading level0 row1" >(4063.2, 9825.4]</th>
#       <td id="T_bcab8_row1_col0" class="data row1 col0" >431</td>
#       <td id="T_bcab8_row1_col1" class="data row1 col1" >1725.080432</td>
#       <td id="T_bcab8_row1_col2" class="data row1 col2" >67.411269</td>
#       <td id="T_bcab8_row1_col3" class="data row1 col3" >187.520367</td>
#       <td id="T_bcab8_row1_col4" class="data row1 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_bcab8_level0_row2" class="row_heading level0 row2" >(9825.4, 24299.0]</th>
#       <td id="T_bcab8_row2_col0" class="data row2 col0" >432</td>
#       <td id="T_bcab8_row2_col1" class="data row2 col1" >1395.285364</td>
#       <td id="T_bcab8_row2_col2" class="data row2 col2" >65.804632</td>
#       <td id="T_bcab8_row2_col3" class="data row2 col3" >-142.274702</td>
#       <td id="T_bcab8_row2_col4" class="data row2 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_bcab8_level0_row3" class="row_heading level0 row3" >(24299.0, 43519.8]</th>
#       <td id="T_bcab8_row3_col0" class="data row3 col0" >430</td>
#       <td id="T_bcab8_row3_col1" class="data row3 col1" >1141.553935</td>
#       <td id="T_bcab8_row3_col2" class="data row3 col2" >13.742028</td>
#       <td id="T_bcab8_row3_col3" class="data row3 col3" >-396.006130</td>
#       <td id="T_bcab8_row3_col4" class="data row3 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_bcab8_level0_row4" class="row_heading level0 row4" >(43519.8, 190000.0]</th>
#       <td id="T_bcab8_row4_col0" class="data row4 col0" >432</td>
#       <td id="T_bcab8_row4_col1" class="data row4 col1" >990.635754</td>
#       <td id="T_bcab8_row4_col2" class="data row4 col2" >169.615201</td>
#       <td id="T_bcab8_row4_col3" class="data row4 col3" >-546.924311</td>
#       <td id="T_bcab8_row4_col4" class="data row4 col4" >1537.560066</td>
#     </tr>
#   </tbody>
# </table>

# %%
print_error('fuelType')
# Out:
# <style type="text/css">
# #T_cb4b5_row0_col3 {
#   background-color: #b10d0d;
#   color: #f1f1f1;
# }
# #T_cb4b5_row1_col3 {
#   background-color: #d00808;
#   color: #f1f1f1;
# }
# #T_cb4b5_row2_col3 {
#   background-color: #312222;
#   color: #f1f1f1;
# }
# #T_cb4b5_row3_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cb4b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb4b5_level0_col0" class="col_heading level0 col0" >error_abs_count</th>
#       <th id="T_cb4b5_level0_col1" class="col_heading level0 col1" >error_abs_mean</th>
#       <th id="T_cb4b5_level0_col2" class="col_heading level0 col2" >error_mean</th>
#       <th id="T_cb4b5_level0_col3" class="col_heading level0 col3" >mean_error_diff</th>
#       <th id="T_cb4b5_level0_col4" class="col_heading level0 col4" >mean_error</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >fuelType</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb4b5_level0_row0" class="row_heading level0 row0" >Diesel</th>
#       <td id="T_cb4b5_row0_col0" class="data row0 col0" >1394</td>
#       <td id="T_cb4b5_row0_col1" class="data row0 col1" >1437.061117</td>
#       <td id="T_cb4b5_row0_col2" class="data row0 col2" >98.276014</td>
#       <td id="T_cb4b5_row0_col3" class="data row0 col3" >-100.498949</td>
#       <td id="T_cb4b5_row0_col4" class="data row0 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_cb4b5_level0_row1" class="row_heading level0 row1" >Hybrid</th>
#       <td id="T_cb4b5_row1_col0" class="data row1 col0" >64</td>
#       <td id="T_cb4b5_row1_col1" class="data row1 col1" >1558.853198</td>
#       <td id="T_cb4b5_row1_col2" class="data row1 col2" >-352.158801</td>
#       <td id="T_cb4b5_row1_col3" class="data row1 col3" >21.293132</td>
#       <td id="T_cb4b5_row1_col4" class="data row1 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_cb4b5_level0_row2" class="row_heading level0 row2" >Other</th>
#       <td id="T_cb4b5_row2_col0" class="data row2 col0" >5</td>
#       <td id="T_cb4b5_row2_col1" class="data row2 col1" >944.136410</td>
#       <td id="T_cb4b5_row2_col2" class="data row2 col2" >-941.902308</td>
#       <td id="T_cb4b5_row2_col3" class="data row2 col3" >-593.423655</td>
#       <td id="T_cb4b5_row2_col4" class="data row2 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_cb4b5_level0_row3" class="row_heading level0 row3" >Petrol</th>
#       <td id="T_cb4b5_row3_col0" class="data row3 col0" >694</td>
#       <td id="T_cb4b5_row3_col1" class="data row3 col1" >1741.738585</td>
#       <td id="T_cb4b5_row3_col2" class="data row3 col2" >221.317702</td>
#       <td id="T_cb4b5_row3_col3" class="data row3 col3" >204.178520</td>
#       <td id="T_cb4b5_row3_col4" class="data row3 col4" >1537.560066</td>
#     </tr>
#   </tbody>
# </table>

# %%
test['tax_group'] = pd.qcut(test['tax'],5,duplicates='drop')

# %%
print_error('tax_group')
# Out:
# <style type="text/css">
# #T_7fa2c_row0_col3 {
#   background-color: #312222;
#   color: #f1f1f1;
# }
# #T_7fa2c_row1_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_7fa2c_row2_col3 {
#   background-color: #eb0303;
#   color: #f1f1f1;
# }
# #T_7fa2c_row3_col3 {
#   background-color: #d50707;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7fa2c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7fa2c_level0_col0" class="col_heading level0 col0" >error_abs_count</th>
#       <th id="T_7fa2c_level0_col1" class="col_heading level0 col1" >error_abs_mean</th>
#       <th id="T_7fa2c_level0_col2" class="col_heading level0 col2" >error_mean</th>
#       <th id="T_7fa2c_level0_col3" class="col_heading level0 col3" >mean_error_diff</th>
#       <th id="T_7fa2c_level0_col4" class="col_heading level0 col4" >mean_error</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tax_group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7fa2c_level0_row0" class="row_heading level0 row0" >(-0.001, 125.0]</th>
#       <td id="T_7fa2c_row0_col0" class="data row0 col0" >512</td>
#       <td id="T_7fa2c_row0_col1" class="data row0 col1" >823.722414</td>
#       <td id="T_7fa2c_row0_col2" class="data row0 col2" >91.176598</td>
#       <td id="T_7fa2c_row0_col3" class="data row0 col3" >-713.837651</td>
#       <td id="T_7fa2c_row0_col4" class="data row0 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_7fa2c_level0_row1" class="row_heading level0 row1" >(125.0, 145.0]</th>
#       <td id="T_7fa2c_row1_col0" class="data row1 col0" >1131</td>
#       <td id="T_7fa2c_row1_col1" class="data row1 col1" >1807.424736</td>
#       <td id="T_7fa2c_row1_col2" class="data row1 col2" >117.301327</td>
#       <td id="T_7fa2c_row1_col3" class="data row1 col3" >269.864670</td>
#       <td id="T_7fa2c_row1_col4" class="data row1 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_7fa2c_level0_row2" class="row_heading level0 row2" >(145.0, 150.0]</th>
#       <td id="T_7fa2c_row2_col0" class="data row2 col0" >252</td>
#       <td id="T_7fa2c_row2_col1" class="data row2 col1" >1707.575874</td>
#       <td id="T_7fa2c_row2_col2" class="data row2 col2" >118.514950</td>
#       <td id="T_7fa2c_row2_col3" class="data row2 col3" >170.015808</td>
#       <td id="T_7fa2c_row2_col4" class="data row2 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_7fa2c_level0_row3" class="row_heading level0 row3" >(150.0, 580.0]</th>
#       <td id="T_7fa2c_row3_col0" class="data row3 col0" >262</td>
#       <td id="T_7fa2c_row3_col1" class="data row3 col1" >1604.063700</td>
#       <td id="T_7fa2c_row3_col2" class="data row3 col2" >206.593848</td>
#       <td id="T_7fa2c_row3_col3" class="data row3 col3" >66.503634</td>
#       <td id="T_7fa2c_row3_col4" class="data row3 col4" >1537.560066</td>
#     </tr>
#   </tbody>
# </table>

# %%
test['mpg_group'] = pd.qcut(test['mpg'],5)

# %%
print_error('mpg_group')
# Out:
# <style type="text/css">
# #T_b6245_row0_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# #T_b6245_row1_col3 {
#   background-color: #a40f0f;
#   color: #f1f1f1;
# }
# #T_b6245_row2_col3 {
#   background-color: #881414;
#   color: #f1f1f1;
# }
# #T_b6245_row3_col3 {
#   background-color: #551c1c;
#   color: #f1f1f1;
# }
# #T_b6245_row4_col3 {
#   background-color: #312222;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b6245">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6245_level0_col0" class="col_heading level0 col0" >error_abs_count</th>
#       <th id="T_b6245_level0_col1" class="col_heading level0 col1" >error_abs_mean</th>
#       <th id="T_b6245_level0_col2" class="col_heading level0 col2" >error_mean</th>
#       <th id="T_b6245_level0_col3" class="col_heading level0 col3" >mean_error_diff</th>
#       <th id="T_b6245_level0_col4" class="col_heading level0 col4" >mean_error</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >mpg_group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6245_level0_row0" class="row_heading level0 row0" >(5.499, 42.2]</th>
#       <td id="T_b6245_row0_col0" class="data row0 col0" >444</td>
#       <td id="T_b6245_row0_col1" class="data row0 col1" >2159.412978</td>
#       <td id="T_b6245_row0_col2" class="data row0 col2" >227.429403</td>
#       <td id="T_b6245_row0_col3" class="data row0 col3" >621.852912</td>
#       <td id="T_b6245_row0_col4" class="data row0 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_b6245_level0_row1" class="row_heading level0 row1" >(42.2, 50.4]</th>
#       <td id="T_b6245_row1_col0" class="data row1 col0" >487</td>
#       <td id="T_b6245_row1_col1" class="data row1 col1" >1664.200649</td>
#       <td id="T_b6245_row1_col2" class="data row1 col2" >361.406267</td>
#       <td id="T_b6245_row1_col3" class="data row1 col3" >126.640583</td>
#       <td id="T_b6245_row1_col4" class="data row1 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_b6245_level0_row2" class="row_heading level0 row2" >(50.4, 55.4]</th>
#       <td id="T_b6245_row2_col0" class="data row2 col0" >380</td>
#       <td id="T_b6245_row2_col1" class="data row2 col1" >1517.852124</td>
#       <td id="T_b6245_row2_col2" class="data row2 col2" >46.756860</td>
#       <td id="T_b6245_row2_col3" class="data row2 col3" >-19.707942</td>
#       <td id="T_b6245_row2_col4" class="data row2 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_b6245_level0_row3" class="row_heading level0 row3" >(55.4, 64.2]</th>
#       <td id="T_b6245_row3_col0" class="data row3 col0" >449</td>
#       <td id="T_b6245_row3_col1" class="data row3 col1" >1238.191642</td>
#       <td id="T_b6245_row3_col2" class="data row3 col2" >-105.163252</td>
#       <td id="T_b6245_row3_col3" class="data row3 col3" >-299.368424</td>
#       <td id="T_b6245_row3_col4" class="data row3 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_b6245_level0_row4" class="row_heading level0 row4" >(64.2, 470.8]</th>
#       <td id="T_b6245_row4_col0" class="data row4 col0" >397</td>
#       <td id="T_b6245_row4_col1" class="data row4 col1" >1044.181685</td>
#       <td id="T_b6245_row4_col2" class="data row4 col2" >39.825594</td>
#       <td id="T_b6245_row4_col3" class="data row4 col3" >-493.378380</td>
#       <td id="T_b6245_row4_col4" class="data row4 col4" >1537.560066</td>
#     </tr>
#   </tbody>
# </table>

# %%
test.groupby('mpg_group')[['price','year']].agg(['count','mean'])
# Out:
#               price                year
#               count          mean count         mean
# mpg_group
# (5.499, 42.2]   444  32876.211712   444  2017.743243
# (42.2, 50.4]    487  23569.260780   487  2017.451745
# (50.4, 55.4]    380  21489.018421   380  2017.194737
# (55.4, 64.2]    449  18276.222717   449  2016.443207
# (64.2, 470.8]   397  16704.297229   397  2016.727960

# %%
test.groupby('year')['mpg'].agg(['count','mean'])
# Out:
#       count       mean
# year
# 1996      1  26.400000
# 1999      1  31.000000
# 2001      1  27.700000
# 2002      2  28.950000
# 2003      1  26.400000
# 2004      4  27.125000
# 2006      3  37.566667
# 2007      2  36.850000
# 2008      4  41.075000
# 2009      6  42.366667
# 2010      3  47.200000
# 2011     12  52.791667
# 2012     28  56.100000
# 2013     73  55.279452
# 2014     97  55.529897
# 2015    179  60.846927
# 2016    360  63.877222
# 2017    330  65.586667
# 2018    168  50.624405
# 2019    726  50.093113
# 2020    156  45.766026

# %%
test.groupby('year')['mpg'].mean().plot()
# Out:
# <AxesSubplot: xlabel='year'>

# %%
test['engineSize'].value_counts()
# Out:
# 2.0    1323
# 3.0     495
# 1.5     278
# 1.6      24
# 4.4      15
# 0.0       7
# 2.5       4
# 2.2       3
# 2.8       2
# 3.2       2
# 4.0       2
# 0.6       1
# 6.6       1
# Name: engineSize, dtype: int64

# %%
test['engine_group'] = pd.cut(test['engineSize'],[0,1.5,2,float('inf')])

# %%
print_error('engine_group')
# Out:
# <style type="text/css">
# #T_4c6f2_row0_col3 {
#   background-color: #312222;
#   color: #f1f1f1;
# }
# #T_4c6f2_row1_col3 {
#   background-color: #721717;
#   color: #f1f1f1;
# }
# #T_4c6f2_row2_col3 {
#   background-color: #ff0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4c6f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c6f2_level0_col0" class="col_heading level0 col0" >error_abs_count</th>
#       <th id="T_4c6f2_level0_col1" class="col_heading level0 col1" >error_abs_mean</th>
#       <th id="T_4c6f2_level0_col2" class="col_heading level0 col2" >error_mean</th>
#       <th id="T_4c6f2_level0_col3" class="col_heading level0 col3" >mean_error_diff</th>
#       <th id="T_4c6f2_level0_col4" class="col_heading level0 col4" >mean_error</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >engine_group</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c6f2_level0_row0" class="row_heading level0 row0" >(0.0, 1.5]</th>
#       <td id="T_4c6f2_row0_col0" class="data row0 col0" >279</td>
#       <td id="T_4c6f2_row0_col1" class="data row0 col1" >1135.531674</td>
#       <td id="T_4c6f2_row0_col2" class="data row0 col2" >149.248281</td>
#       <td id="T_4c6f2_row0_col3" class="data row0 col3" >-402.028392</td>
#       <td id="T_4c6f2_row0_col4" class="data row0 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_4c6f2_level0_row1" class="row_heading level0 row1" >(1.5, 2.0]</th>
#       <td id="T_4c6f2_row1_col0" class="data row1 col0" >1347</td>
#       <td id="T_4c6f2_row1_col1" class="data row1 col1" >1423.236324</td>
#       <td id="T_4c6f2_row1_col2" class="data row1 col2" >60.610112</td>
#       <td id="T_4c6f2_row1_col3" class="data row1 col3" >-114.323742</td>
#       <td id="T_4c6f2_row1_col4" class="data row1 col4" >1537.560066</td>
#     </tr>
#     <tr>
#       <th id="T_4c6f2_level0_row2" class="row_heading level0 row2" >(2.0, inf]</th>
#       <td id="T_4c6f2_row2_col0" class="data row2 col0" >524</td>
#       <td id="T_4c6f2_row2_col1" class="data row2 col1" >2049.868683</td>
#       <td id="T_4c6f2_row2_col2" class="data row2 col2" >265.297889</td>
#       <td id="T_4c6f2_row2_col3" class="data row2 col3" >512.308617</td>
#       <td id="T_4c6f2_row2_col4" class="data row2 col4" >1537.560066</td>
#     </tr>
#   </tbody>
# </table>

# %%
test.groupby('year')['engineSize'].mean().plot()
# Out:
# <AxesSubplot: xlabel='year'>

# %% [markdown]
# # Feature importances

# %%
model.get_feature_importance(prettified=True)
# Out:
#      Feature Id  Importances
# 0          year    21.663393
# 1    engineSize    19.886510
# 2       mileage    17.956035
# 3         model    16.587238
# 4           mpg    14.284600
# 5      fuelType     4.843232
# 6  transmission     3.381356
# 7           tax     1.397635

# %% [markdown]
# # hap
